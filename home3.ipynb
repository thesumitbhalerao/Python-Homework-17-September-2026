# %%
name="sumit"
age=21
city="pune"
print(name)
print(age)
print(city)
# Out:
# sumit
# 21
# pune

# %%
print(type(name))
print(type(age))
print(type(city))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'str'>

# %%
print(id(name))
print(id(age))
print(id(city))
# Out:
# 2583955006608
# 140718052599544
# 2583955013040
