# %%
a=20
b=30
print(a+b)
print(a*b)
print(a-b)
print(a/b)
# Out:
# 50
# 600
# -10
# 0.6666666666666666

# %%
result=a+b
print(type(result))
# Out:
# <class 'int'>

# %%
print(id(a))
print(id(b))
print(id(result))
# Out:
# 140719023384280
# 140719023384600
# 140719023385240
