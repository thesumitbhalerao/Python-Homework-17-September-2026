# %%
name="sumit"
weight=56.98
is_student=True
print(name)
print(weight)
print(is_student)
# Out:
# sumit
# 56.98
# True

# %%
print(type(name))
print(type(weight))
print(type(is_student))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
print(id(name))
print(id(weight))
print(id(is_student))
# Out:
# 2470917497424
# 2470916690896
# 140719009049344
